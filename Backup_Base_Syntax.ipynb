# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcoLord97/Python_Programming/blob/main/Backup_Base_Syntax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print(x + 1)   # Addition
#print(x - 1)   # Subtraction
#print(x * 2)   # Multiplication
#print(x ** 2)  # Exponentiation

#print(t and f) # Logical AND;
#print(t or f)  # Logical OR;
#print(not t)   # Logical NOT;
#print(t != f)  # Logical XOR;

#s = "hello"
#print(s.capitalize())  # Capitalize a string "hello"
#print(s.upper())       # Convert a string to uppercase; prints "HELLO"
#print(s.rjust(7))      # Right-justify a string, padding with spaces "hello"
#print(s.center(7))     # Center a string, padding with spaces "hello"
#print(s.replace('l', '(ell)'))  # Replace all instances of one substring with another "he(ell)(ell)o"
#print('  world '.strip())  # Strip leading and trailing whitespace "world"

x = 3

print(x**3, type(x))
print("vamos sputtacchios")
# Out:
# 27 <class 'int'>
# vamos sputtacchios
